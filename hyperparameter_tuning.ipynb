# %%
# Check core SDK version number
import azureml.core

print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.20.0

# %%
from azureml.telemetry import set_diagnostics_collection

set_diagnostics_collection(send_diagnostics=True)
# Out:
# Turning diagnostics collection on.

# %%
from azureml.core.workspace import Workspace

ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep = '\n')
# Out:
# Workspace name: quick-starts-ws-139150
# Azure region: southcentralus
# Subscription id: 6b4af8be-9931-443e-90f6-c4c34a1f9737
# Resource group: aml-quickstarts-139150

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# choose a name for your cluster
cluster_name = "compute-cluster"

try:
    compute_target = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing compute target')
except ComputeTargetException:
    print('Creating a new compute target...')
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2', 
                                                           max_nodes=4)

    # create the cluster
    compute_target = ComputeTarget.create(ws, cluster_name, compute_config)

# can poll for a minimum number of nodes and for a specific timeout. 
# if no min node count is provided it uses the scale settings for the cluster
compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)

# use get_status() to get a detailed status for the current cluster. 
print(compute_target.get_status().serialize())
# Out:
# Found existing compute target
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned
# {'currentNodeCount': 0, 'targetNodeCount': 0, 'nodeStateCounts': {'preparingNodeCount': 0, 'runningNodeCount': 0, 'idleNodeCount': 0, 'unusableNodeCount': 0, 'leavingNodeCount': 0, 'preemptedNodeCount': 0}, 'allocationState': 'Steady', 'allocationStateTransitionTime': '2021-02-18T22:12:17.082000+00:00', 'errors': None, 'creationTime': '2021-02-18T22:12:14.009612+00:00', 'modifiedTime': '2021-02-18T22:12:29.882838+00:00', 'provisioningState': 'Succeeded', 'provisioningStateTransitionTime': None, 'scaleSettings': {'minNodeCount': 0, 'maxNodeCount': 4, 'nodeIdleTimeBeforeScaleDown': 'PT120S'}, 'vmPriority': 'Dedicated', 'vmSize': 'STANDARD_DS3_V2'}

# %%
import os

project_folder = './capstone-project'
os.makedirs(project_folder, exist_ok=True)

# %%
import shutil

shutil.copy('train.py', project_folder)
# Out:
# './capstone-project/train.py'

# %% [markdown]
# # Create an experiment

# %%
from azureml.core import Experiment

experiment_name = 'House_Price_Predication'
experiment = Experiment(ws, name=experiment_name)

# %% [markdown]
# ## Create an environment
# Define a conda environment YAML file with your training script dependencies and create an Azure ML environment.

# %%
# %%writefile conda_dependencies.yml
#
# # Conda environment specification. The dependencies defined in this file will
# # be automatically provisioned for runs with userManagedDependencies=False.
#
# # Details about the Conda environment file format:
# # https://conda.io/docs/user-guide/tasks/manage-environments.html#create-env-file-manually
#
# name: project_environment
# dependencies:
#   # The python interpreter version.
#   # Currently Azure ML only supports 3.5.2 and later.
# - python=3.6.2
#
# - pip:
#   - azureml-train-automl-runtime==1.21.0
#   - inference-schema
#   - azureml-interpret==1.21.0
#   - azureml-defaults==1.21.0
# - numpy>=1.16.0,<1.19.0
# - pandas==0.25.1
# - scikit-learn==0.22.1
# - xgboost<=1.3.3
# - psutil>=5.2.2,<6.0.0
# channels:
# - anaconda
# - conda-forge
# Out:
# Overwriting conda_dependencies.yml

# %%
from azureml.core import Environment

sklearn_env = Environment.from_conda_specification(name = 'capstone-project-env', file_path = './conda_dependencies.yml')

# %%
from azureml.core import ScriptRunConfig

src = ScriptRunConfig(source_directory=project_folder,
                      script='train.py',
                      arguments=['--kernel', 'linear', '--penalty', 1.0],
                      compute_target=compute_target,
                      environment=sklearn_env)

# %%
run = experiment.submit(src)

# %%
#https://github.com/Azure/MachineLearningNotebooks/blob/master/how-to-use-azureml/ml-frameworks/scikit-learn/train-hyperparameter-tune-deploy-with-sklearn/train-hyperparameter-tune-deploy-with-sklearn.ipynb

# %% [markdown]
# # Monitor The Run

# %%
from azureml.widgets import RunDetails

RunDetails(run).show()
run.wait_for_completion(show_output=True)
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': True, 'log_level': 'INFO', 's…
# RunId: House_Price_Predication_1613688085_86008573
# Web View: https://ml.azure.com/experiments/House_Price_Predication/runs/House_Price_Predication_1613688085_86008573?wsid=/subscriptions/6b4af8be-9931-443e-90f6-c4c34a1f9737/resourcegroups/aml-quickstarts-139150/workspaces/quick-starts-ws-139150
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2021/02/18 22:41:30 Downloading source code...
# 2021/02/18 22:41:31 Finished downloading source code
# 2021/02/18 22:41:32 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/02/18 22:41:32 Successfully set up Docker network: acb_default_network
# 2021/02/18 22:41:32 Setting up Docker configuration...
# 2021/02/18 22:41:33 Successfully set up Docker configuration
# 2021/02/18 22:41:33 Logging in to registry: 8ee44115daec45588f306316a3c9ed45.azurecr.io
# 2021/02/18 22:41:34 Successfully logged into 8ee44115daec45588f306316a3c9ed45.azurecr.io
# 2021/02/18 22:41:34 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/02/18 22:41:34 Scanning for dependencies...
# 2021/02/18 22:41:35 Successfully scanned dependencies
# 2021/02/18 22:41:35 Launching container with name: acb_step_0
# Sending build context to Docker daemon  65.02kB
#
# Step 1/15 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# 05895bb28c18: Waiting
# baf7ab26f516: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# d54d011de0e3: Verifying Checksum
# d54d011de0e3: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# be8ec4e48d7f: Pull complete
# 33b8b485aff0: Pull complete
# d887158cc58c: Pull complete
# 05895bb28c18: Pull complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# Digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1@sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#  ---> 138ae4912094
# Step 2/15 : USER root
#  ---> Running in 6e0ee117db10
# Removing intermediate container 6e0ee117db10
#  ---> fa3061e82126
# Step 3/15 : RUN mkdir -p $HOME/.cache
#  ---> Running in 0f912d76be4a
# Removing intermediate container 0f912d76be4a
#  ---> ca218868f869
# Step 4/15 : WORKDIR /
#  ---> Running in 8549d8660a69
# Removing intermediate container 8549d8660a69
#  ---> 85188df3694d
# Step 5/15 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> d29fe73a28e0
# Step 6/15 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 0f1380540d2a
# Removing intermediate container 0f1380540d2a
#  ---> be3d25db72c6
# Step 7/15 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 7d5fe02c68c6
# Step 8/15 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 414cb41d1900
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# pandas-0.25.1        | 11.4 MB   |            |   0%
# pandas-0.25.1        | 11.4 MB   |            |   0%
# pandas-0.25.1        | 11.4 MB   | ####       |  40%
# pandas-0.25.1        | 11.4 MB   | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | 1          |   2%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# _py-xgboost-mutex-2. | 9 KB      |            |   0%
# _py-xgboost-mutex-2. | 9 KB      | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# psutil-5.7.2         | 342 KB    |            |   0%
# psutil-5.7.2         | 342 KB    | ########## | 100%
#
# _openmp_mutex-4.5    | 22 KB     |            |   0%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# python_abi-3.6       | 4 KB      |            |   0%
# python_abi-3.6       | 4 KB      | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# scikit-learn-0.22.1  | 7.1 MB    |            |   0%
# scikit-learn-0.22.1  | 7.1 MB    | #######7   |  77%
# scikit-learn-0.22.1  | 7.1 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# libgcc-ng-9.3.0      | 7.8 MB    |            |   0%
# libgcc-ng-9.3.0      | 7.8 MB    | ######7    |  67%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##         |  20%
# python-3.6.2         | 27.0 MB   | #####5     |  56%
# python-3.6.2         | 27.0 MB   | ########6  |  87%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# libstdcxx-ng-9.3.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ########## | 100%
#
# py-xgboost-1.3.0     | 123 KB    |            |   0%
# py-xgboost-1.3.0     | 123 KB    | ########## | 100%
#
# xgboost-1.3.0        | 11 KB     |            |   0%
# xgboost-1.3.0        | 11 KB     | ########## | 100%
#
# libxgboost-1.3.0     | 3.3 MB    |            |   0%
# libxgboost-1.3.0     | 3.3 MB    | #########7 |  97%
# libxgboost-1.3.0     | 3.3 MB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   2%
# mkl-2019.4           | 204.1 MB  | 6          |   7%
# mkl-2019.4           | 204.1 MB  | #          |  10%
# mkl-2019.4           | 204.1 MB  | #4         |  14%
# mkl-2019.4           | 204.1 MB  | #8         |  18%
# mkl-2019.4           | 204.1 MB  | ##2        |  23%
# mkl-2019.4           | 204.1 MB  | ##6        |  26%
# mkl-2019.4           | 204.1 MB  | ###        |  30%
# mkl-2019.4           | 204.1 MB  | ###5       |  35%
# mkl-2019.4           | 204.1 MB  | ###9       |  40%
# mkl-2019.4           | 204.1 MB  | ####3      |  44%
# mkl-2019.4           | 204.1 MB  | ####8      |  48%
# mkl-2019.4           | 204.1 MB  | #####2     |  52%
# mkl-2019.4           | 204.1 MB  | #####6     |  56%
# mkl-2019.4           | 204.1 MB  | ######     |  61%
# mkl-2019.4           | 204.1 MB  | ######4    |  65%
# mkl-2019.4           | 204.1 MB  | ######8    |  68%
# mkl-2019.4           | 204.1 MB  | #######1   |  72%
# mkl-2019.4           | 204.1 MB  | #######4   |  75%
# mkl-2019.4           | 204.1 MB  | #######7   |  77%
# mkl-2019.4           | 204.1 MB  | ########1  |  81%
# mkl-2019.4           | 204.1 MB  | ########4  |  85%
# mkl-2019.4           | 204.1 MB  | ########7  |  88%
# mkl-2019.4           | 204.1 MB  | #########1 |  92%
# mkl-2019.4           | 204.1 MB  | #########6 |  96%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ######7    |  68%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# numpy-base-1.18.5    | 5.1 MB    |            |   0%
# numpy-base-1.18.5    | 5.1 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# libgomp-9.3.0        | 376 KB    |            |   0%
# libgomp-9.3.0        | 376 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | 4          |   4%
# scipy-1.5.2          | 18.5 MB   | ##7        |  28%
# scipy-1.5.2          | 18.5 MB   | ####5      |  45%
# scipy-1.5.2          | 18.5 MB   | ######3    |  63%
# scipy-1.5.2          | 18.5 MB   | ########8  |  88%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# numpy-1.18.5         | 4 KB      |            |   0%
# numpy-1.18.5         | 4 KB      | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv._vz1s8d2.requirements.txt']
# Pip subprocess output:
# Collecting azureml-train-automl-runtime==1.21.0
#   Downloading azureml_train_automl_runtime-1.21.0-py3-none-any.whl (137 kB)
# Collecting inference-schema
#   Downloading inference_schema-1.1.0-py3-none-any.whl (19 kB)
# Collecting azureml-interpret==1.21.0
#   Downloading azureml_interpret-1.21.0-py3-none-any.whl (46 kB)
# Collecting azureml-defaults==1.21.0
#   Downloading azureml_defaults-1.21.0-py3-none-any.whl (3.1 kB)
# Collecting botocore<=1.18.18
#   Downloading botocore-1.18.18-py2.py3-none-any.whl (6.7 MB)
# Collecting azureml-core~=1.21.0
#   Downloading azureml_core-1.21.0.post2-py3-none-any.whl (2.1 MB)
# Requirement already satisfied, skipping upgrade: scikit-learn<0.23.0,>=0.19.0 in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.21.0->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 1)) (0.22.1)
# Collecting azureml-dataset-runtime[fuse,pandas]~=1.21.0
#   Downloading azureml_dataset_runtime-1.21.0-py3-none-any.whl (3.5 kB)
# Collecting onnx<=1.7.0,>=1.5.0
#   Downloading onnx-1.7.0-cp36-cp36m-manylinux1_x86_64.whl (7.4 MB)
# Requirement already satisfied, skipping upgrade: scipy<=1.5.2,>=1.0.0 in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.21.0->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 1)) (1.5.2)
# Collecting smart-open<=1.9.0
#   Downloading smart_open-1.9.0.tar.gz (70 kB)
# Collecting onnxconverter-common<=1.6.0,>=1.4.2
#   Downloading onnxconverter_common-1.6.0-py2.py3-none-any.whl (43 kB)
# Collecting onnxmltools==1.4.1
#   Downloading onnxmltools-1.4.1-py2.py3-none-any.whl (371 kB)
# Requirement already satisfied, skipping upgrade: numpy<1.19.0,>=1.16.0 in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.21.0->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 1)) (1.18.5)
# Collecting azureml-automl-core~=1.21.0
#   Downloading azureml_automl_core-1.21.0-py3-none-any.whl (196 kB)
# Collecting boto3<=1.15.18
#   Downloading boto3-1.15.18-py2.py3-none-any.whl (129 kB)
# Collecting gensim<3.9.0
#   Downloading gensim-3.8.3-cp36-cp36m-manylinux1_x86_64.whl (24.2 MB)
# Collecting statsmodels<=0.10.2,>=0.9.0
#   Downloading statsmodels-0.10.2-cp36-cp36m-manylinux1_x86_64.whl (8.1 MB)
# Collecting lightgbm<=2.3.0,>=2.0.11
#   Downloading lightgbm-2.3.0-py2.py3-none-manylinux1_x86_64.whl (1.3 MB)
# Collecting onnxruntime==1.3.0
#   Downloading onnxruntime-1.3.0-cp36-cp36m-manylinux1_x86_64.whl (3.9 MB)
# Collecting azureml-telemetry~=1.21.0
#   Downloading azureml_telemetry-1.21.0-py3-none-any.whl (30 kB)
# Collecting azureml-automl-runtime~=1.21.0
#   Downloading azureml_automl_runtime-1.21.0-py3-none-any.whl (2.0 MB)
# Collecting sklearn-pandas<=1.7.0,>=1.4.0
#   Downloading sklearn_pandas-1.7.0-py2.py3-none-any.whl (10 kB)
# Collecting skl2onnx==1.4.9
#   Downloading skl2onnx-1.4.9-py2.py3-none-any.whl (114 kB)
# Collecting azureml-train-automl-client~=1.21.0
#   Downloading azureml_train_automl_client-1.21.0-py3-none-any.whl (115 kB)
# Collecting keras2onnx<=1.6.0,>=1.4.0
#   Downloading keras2onnx-1.6.0-py3-none-any.whl (219 kB)
# Requirement already satisfied, skipping upgrade: pandas<1.0.0,>=0.21.0 in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from azureml-train-automl-runtime==1.21.0->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 1)) (0.25.1)
# Collecting azure-storage-queue~=12.1
#   Downloading azure_storage_queue-12.1.5-py2.py3-none-any.whl (132 kB)
# Collecting jinja2<=2.11.2
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.3 in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from inference-schema->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 2)) (2.8.1)
# Collecting wrapt==1.11.1
#   Downloading wrapt-1.11.1.tar.gz (27 kB)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from inference-schema->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 2)) (2020.1)
# Collecting interpret-community==0.16.*
#   Downloading interpret_community-0.16.0-py3-none-any.whl (5.9 MB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting urllib3<1.26,>=1.20; python_version != "3.4"
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting docker
#   Downloading docker-4.4.3-py2.py3-none-any.whl (146 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.0.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.4.6-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting requests>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from scikit-learn<0.23.0,>=0.19.0->azureml-train-automl-runtime==1.21.0->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 1)) (0.17.0)
# Collecting azureml-dataprep<2.9.0a,>=2.8.0a
#   Downloading azureml_dataprep-2.8.3-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Requirement already satisfied, skipping upgrade: six in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from onnx<=1.7.0,>=1.5.0->azureml-train-automl-runtime==1.21.0->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 1)) (1.15.0)
# Collecting typing-extensions>=3.6.2.1
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting protobuf
#   Downloading protobuf-3.15.0-cp36-cp36m-manylinux1_x86_64.whl (1.0 MB)
# Collecting boto>=2.32
#   Downloading boto-2.49.0-py2.py3-none-any.whl (1.4 MB)
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading s3transfer-0.3.4-py2.py3-none-any.whl (69 kB)
# Collecting patsy>=0.4.0
#   Downloading patsy-0.5.1-py2.py3-none-any.whl (231 kB)
# Collecting pmdarima==1.1.1
#   Downloading pmdarima-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (682 kB)
# Collecting dill<0.4.0,>=0.2.8
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied, skipping upgrade: psutil<6.0.0,>=5.2.2 in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from azureml-automl-runtime~=1.21.0->azureml-train-automl-runtime==1.21.0->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 1)) (5.7.2)
# Collecting py-cpuinfo==5.0.0
#   Downloading py-cpuinfo-5.0.0.tar.gz (82 kB)
# Collecting nimbusml<=1.8.0,>=1.7.1
#   Downloading nimbusml-1.8.0-cp36-none-manylinux1_x86_64.whl (114.1 MB)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Collecting azure-core<2.0.0,>=1.10.0
#   Downloading azure_core-1.11.0-py2.py3-none-any.whl (127 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting packaging
#   Downloading packaging-20.9-py2.py3-none-any.whl (40 kB)
# Collecting interpret-core[required]<=0.2.1,>=0.1.20
#   Downloading interpret_core-0.2.1-py3-none-any.whl (5.0 MB)
# Collecting shap<=0.34.0,>=0.20.0
#   Downloading shap-0.34.0.tar.gz (264 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.21.0->azureml-train-automl-runtime==1.21.0->-r /azureml-environment-setup/condaenv._vz1s8d2.requirements.txt (line 1)) (2020.6.20)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.4.0-py3-none-any.whl (10 kB)
# Collecting azureml-dataprep-rslex<1.7.0a,>=1.6.0dev0
#   Downloading azureml_dataprep_rslex-1.6.0-cp36-cp36m-manylinux2010_x86_64.whl (8.2 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-native<29.0.0,>=28.0.0
#   Downloading azureml_dataprep_native-28.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting Cython>=0.29
#   Downloading Cython-0.29.21-cp36-cp36m-manylinux1_x86_64.whl (2.0 MB)
# Collecting termcolor
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
# Collecting pyparsing>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
# Collecting tqdm>4.25.0
#   Downloading tqdm-4.57.0-py2.py3-none-any.whl (72 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.9.0-py2.py3-none-any.whl (59 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: smart-open, wrapt, json-logging-py, fusepy, py-cpuinfo, fire, shap, liac-arff, termcolor
#   Building wheel for smart-open (setup.py): started
#   Building wheel for smart-open (setup.py): finished with status 'done'
#   Created wheel for smart-open: filename=smart_open-1.9.0-py3-none-any.whl size=73087 sha256=d5bbf96d3d3bd7475cf9955692ae77e3d9355dee6f3326b79229983a10b76408
#   Stored in directory: /root/.cache/pip/wheels/8e/9f/cd/dbf5c1362c59abb699a218c1151679033b8ccb5b6db559d512
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.11.1-cp36-cp36m-linux_x86_64.whl size=66718 sha256=5949fdfd7d21ee6de840ceb55a9ec04e62ff648998b9582a46d42fa185358690
#   Stored in directory: /root/.cache/pip/wheels/94/0f/ec/66085641573800014bb0c8b657f3366eff641c42df79abbfe9
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=346d6f6f4123ac36bceecc5b7d0028acd790ee9f515e6eb1877a1496275be540
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=7468170fc686806e2965057ee60b59816518aed90ea6cf0252004177b321d675
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for py-cpuinfo (setup.py): started
#   Building wheel for py-cpuinfo (setup.py): finished with status 'done'
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-5.0.0-py3-none-any.whl size=18683 sha256=b9dfaea085fee2e243fc158500ec95a1c2ff4d100282af48f2729fad6d2ae440
#   Stored in directory: /root/.cache/pip/wheels/e6/54/db/65176a1697a583d8ec5f90510f6faab11cda739d0e4f0ba2ea
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=36d39079be74af60c6831451d45a4bd27c518f3a9f5186eca64f191a1a00b015
#   Stored in directory: /root/.cache/pip/wheels/a6/12/74/ce0728e3990845862240349a12d7179a262e388ec73938024b
#   Building wheel for shap (setup.py): started
#   Building wheel for shap (setup.py): finished with status 'done'
#   Created wheel for shap: filename=shap-0.34.0-cp36-cp36m-linux_x86_64.whl size=387810 sha256=4c0ee6b49b0ea6f42a8041a14e9e5a21117976c3294b8d07e43fb5ba5992b8e9
#   Stored in directory: /root/.cache/pip/wheels/88/56/c6/630b200696678c506f3057a1e7573c086e50d59fdcffcbfd04
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=3514d5644150f9c6072f2d2b2c10814d07e4b1b3f56c7074bad15e977189dcb4
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for termcolor (setup.py): started
#   Building wheel for termcolor (setup.py): finished with status 'done'
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4830 sha256=2e1ebfb80dc979bf47dae47586aea45baa6c35ddae4184c2e261584430795a4e
#   Stored in directory: /root/.cache/pip/wheels/93/2a/eb/e58dbcbc963549ee4f065ff80a59f274cc7210b6eab962acdc
# Successfully built smart-open wrapt json-logging-py fusepy py-cpuinfo fire shap liac-arff termcolor
# Installing collected packages: urllib3, jmespath, botocore, jeepney, pycparser, cffi, cryptography, SecretStorage, pathspec, azure-common, websocket-client, chardet, idna, requests, docker, oauthlib, requests-oauthlib, isodate, msrest, PyJWT, adal, msrestazure, azure-mgmt-containerregistry, contextlib2, azure-mgmt-resource, azure-mgmt-authorization, backports.weakref, backports.tempfile, azure-mgmt-keyvault, ruamel.yaml.clib, ruamel.yaml, azure-mgmt-storage, pyopenssl, pyasn1, ndg-httpsclient, azure-graphrbac, typing-extensions, zipp, importlib-metadata, jsonpickle, azureml-core, azureml-dataprep-rslex, distro, dotnetcore2, azure-core, msal, portalocker, msal-extensions, azure-identity, azureml-dataprep-native, cloudpickle, azureml-dataprep, pyarrow, fusepy, azureml-dataset-runtime, protobuf, onnx, boto, s3transfer, boto3, smart-open, onnxconverter-common, pyparsing, packaging, interpret-core, tqdm, shap, interpret-community, azureml-interpret, skl2onnx, termcolor, fire, keras2onnx, onnxmltools, applicationinsights, azureml-telemetry, azureml-automl-core, gensim, patsy, statsmodels, lightgbm, onnxruntime, Cython, pmdarima, dill, py-cpuinfo, nimbusml, sklearn-pandas, azureml-automl-runtime, liac-arff, azureml-model-management-sdk, json-logging-py, gunicorn, configparser, click, werkzeug, itsdangerous, MarkupSafe, jinja2, flask, azureml-defaults, azureml-train-automl-client, azure-storage-queue, azureml-train-automl-runtime, wrapt, inference-schema
# Successfully installed Cython-0.29.21 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.3.1 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.11.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.0.0 azure-mgmt-storage-11.2.0 azure-storage-queue-12.1.5 azureml-automl-core-1.21.0 azureml-automl-runtime-1.21.0 azureml-core-1.21.0.post2 azureml-dataprep-2.8.3 azureml-dataprep-native-28.0.0 azureml-dataprep-rslex-1.6.0 azureml-dataset-runtime-1.21.0 azureml-defaults-1.21.0 azureml-interpret-1.21.0 azureml-model-management-sdk-1.0.1b6.post1 azureml-telemetry-1.21.0 azureml-train-automl-client-1.21.0 azureml-train-automl-runtime-1.21.0 backports.tempfile-1.0 backports.weakref-1.0.post1 boto-2.49.0 boto3-1.15.18 botocore-1.18.18 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.6 dill-0.3.3 distro-1.5.0 docker-4.4.3 dotnetcore2-2.1.20 fire-0.4.0 flask-1.0.3 fusepy-3.0.1 gensim-3.8.3 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.4.0 inference-schema-1.1.0 interpret-community-0.16.0 interpret-core-0.2.1 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jinja2-2.11.2 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 keras2onnx-1.6.0 liac-arff-2.5.0 lightgbm-2.3.0 msal-1.9.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 nimbusml-1.8.0 oauthlib-3.1.0 onnx-1.7.0 onnxconverter-common-1.6.0 onnxmltools-1.4.1 onnxruntime-1.3.0 packaging-20.9 pathspec-0.8.1 patsy-0.5.1 pmdarima-1.1.1 portalocker-1.7.1 protobuf-3.15.0 py-cpuinfo-5.0.0 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 pyparsing-2.4.7 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 s3transfer-0.3.4 shap-0.34.0 skl2onnx-1.4.9 sklearn-pandas-1.7.0 smart-open-1.9.0 statsmodels-0.10.2 termcolor-1.1.0 tqdm-4.57.0 typing-extensions-3.7.4.3 urllib3-1.25.11 websocket-client-0.57.0 werkzeug-1.0.1 wrapt-1.11.1 zipp-3.4.0
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 414cb41d1900
#  ---> 03869f8d46e2
# Step 9/15 : ENV PATH /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/bin:$PATH
#  ---> Running in 09654943013c
# Removing intermediate container 09654943013c
#  ---> 42025b08bf05
# Step 10/15 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d
#  ---> Running in dea1131b69b9
# Removing intermediate container dea1131b69b9
#  ---> a454b318e604
# Step 11/15 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_c577c941a77ed28f06a40cb408bf519d/lib:$LD_LIBRARY_PATH
#  ---> Running in 38de93122f41
# Removing intermediate container 38de93122f41
#  ---> 626354e80d1b
# Step 12/15 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 7b821d8a7bc4
# Step 13/15 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 61743ccd8132
# Removing intermediate container 61743ccd8132
#  ---> f6c9683b5f09
# Step 14/15 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in f2175168ca81
# Removing intermediate container f2175168ca81
#  ---> 5933c3584e73
# Step 15/15 : CMD ["bash"]
#  ---> Running in 60a0ec1fba52
# Removing intermediate container 60a0ec1fba52
#  ---> 04374a336489
# Successfully built 04374a336489
# Successfully tagged 8ee44115daec45588f306316a3c9ed45.azurecr.io/azureml/azureml_17b7ef3d4500f7b1271481f84603f948:latest
# 2021/02/18 22:46:15 Successfully executed container: acb_step_0
# 2021/02/18 22:46:15 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/02/18 22:46:15 Pushing image: 8ee44115daec45588f306316a3c9ed45.azurecr.io/azureml/azureml_17b7ef3d4500f7b1271481f84603f948:latest, attempt 1
# The push refers to repository [8ee44115daec45588f306316a3c9ed45.azurecr.io/azureml/azureml_17b7ef3d4500f7b1271481f84603f948]
# 9d9c663a4825: Preparing
# 1797d98e86f1: Preparing
# 3fcac5aa0827: Preparing
# 16e6d14508e0: Preparing
# e9a801ca8fe1: Preparing
# 2b95d3be23b4: Preparing
# c9fd473f5354: Preparing
# f449d8429d6e: Preparing
# cbb89d0b53de: Preparing
# 088c5f014be3: Preparing
# 0c7d6f1219f0: Preparing
# e342e7653d41: Preparing
# fc2b9863058f: Preparing
# 8547178b7afb: Preparing
# 1a1a19626b20: Preparing
# 5b7dc8292d9b: Preparing
# bbc674332e2e: Preparing
# da2785b7bb16: Preparing
# e342e7653d41: Waiting
# 2b95d3be23b4: Waiting
# fc2b9863058f: Waiting
# 8547178b7afb: Waiting
# 1a1a19626b20: Waiting
# c9fd473f5354: Waiting
# f449d8429d6e: Waiting
# 5b7dc8292d9b: Waiting
# bbc674332e2e: Waiting
# cbb89d0b53de: Waiting
# 088c5f014be3: Waiting
# da2785b7bb16: Waiting
# 0c7d6f1219f0: Waiting
# 16e6d14508e0: Pushed
# 3fcac5aa0827: Pushed
# e9a801ca8fe1: Pushed
# 9d9c663a4825: Pushed
# 2b95d3be23b4: Pushed
# f449d8429d6e: Pushed
# c9fd473f5354: Pushed
# cbb89d0b53de: Pushed
# fc2b9863058f: Pushed
# 0c7d6f1219f0: Pushed
# 1a1a19626b20: Pushed
# e342e7653d41: Pushed
# 5b7dc8292d9b: Pushed
# bbc674332e2e: Pushed
# 088c5f014be3: Pushed
# da2785b7bb16: Pushed
# 8547178b7afb: Pushed
#
# 1797d98e86f1: Pushed
# latest: digest: sha256:7ed9a8b3227efd88871169aeb9fec695b0561934654512cc34891fd56aef73b8 size: 4095
# 2021/02/18 22:49:20 Successfully pushed image: 8ee44115daec45588f306316a3c9ed45.azurecr.io/azureml/azureml_17b7ef3d4500f7b1271481f84603f948:latest
# 2021/02/18 22:49:20 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 280.769879)
# 2021/02/18 22:49:20 Populating digests for step ID: acb_step_0...
# 2021/02/18 22:49:22 Successfully populated digests for step ID: acb_step_0
# 2021/02/18 22:49:22 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 184.826724)
# 2021/02/18 22:49:22 The following dependencies were found:
# 2021/02/18 22:49:22
# - image:
#     registry: 8ee44115daec45588f306316a3c9ed45.azurecr.io
#     repository: azureml/azureml_17b7ef3d4500f7b1271481f84603f948
#     tag: latest
#     digest: sha256:7ed9a8b3227efd88871169aeb9fec695b0561934654512cc34891fd56aef73b8
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210104.v1
#     digest: sha256:81ca5cdfeefc2a25afff41e66151e97b8a36c0a43d0cd0056af26f01dd37885e
#   git: {}
#
# Run ID: cd4 was successful after 7m53s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_d367b920eebd3237b6d70e3c5f712e53282366890181684bec3c2019b09050c4_d.txt
# ========================================================================================================================
#
# 2021-02-18T22:52:34Z Starting output-watcher...
# 2021-02-18T22:52:34Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-02-18T22:52:35Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-02-18T22:52:35Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_17b7ef3d4500f7b1271481f84603f948
# be8ec4e48d7f: Pulling fs layer
# 33b8b485aff0: Pulling fs layer
# d887158cc58c: Pulling fs layer
# 05895bb28c18: Pulling fs layer
# baf7ab26f516: Pulling fs layer
# 181182e3c9cf: Pulling fs layer
# d584ef274e55: Pulling fs layer
# c445dda55407: Pulling fs layer
# 699b75ff4717: Pulling fs layer
# b177109c9d16: Pulling fs layer
# 59cea07bb66c: Pulling fs layer
# d54d011de0e3: Pulling fs layer
# b34fa6d447e9: Pulling fs layer
# b8bdd3f19218: Pulling fs layer
# 077047c419c8: Pulling fs layer
# dbbe367882c1: Pulling fs layer
# d9ed46e4b5f9: Pulling fs layer
# 6c07d6c25f33: Pulling fs layer
# b177109c9d16: Waiting
# 59cea07bb66c: Waiting
# d54d011de0e3: Waiting
# b34fa6d447e9: Waiting
# b8bdd3f19218: Waiting
# 077047c419c8: Waiting
# dbbe367882c1: Waiting
# d9ed46e4b5f9: Waiting
# 05895bb28c18: Waiting
# 6c07d6c25f33: Waiting
# baf7ab26f516: Waiting
# 181182e3c9cf: Waiting
# d584ef274e55: Waiting
# c445dda55407: Waiting
# 699b75ff4717: Waiting
# d887158cc58c: Verifying Checksum
# d887158cc58c: Download complete
# 33b8b485aff0: Verifying Checksum
# 33b8b485aff0: Download complete
# 05895bb28c18: Verifying Checksum
# 05895bb28c18: Download complete
# be8ec4e48d7f: Verifying Checksum
# be8ec4e48d7f: Download complete
# 181182e3c9cf: Verifying Checksum
# 181182e3c9cf: Download complete
# baf7ab26f516: Verifying Checksum
# baf7ab26f516: Download complete
# d584ef274e55: Verifying Checksum
# d584ef274e55: Download complete
# c445dda55407: Verifying Checksum
# c445dda55407: Download complete
# 59cea07bb66c: Verifying Checksum
# 59cea07bb66c: Download complete
# d54d011de0e3: Download complete
# b34fa6d447e9: Verifying Checksum
# b34fa6d447e9: Download complete
# be8ec4e48d7f: Pull complete
# b177109c9d16: Verifying Checksum
# b177109c9d16: Download complete
# b8bdd3f19218: Verifying Checksum
# b8bdd3f19218: Download complete
# 33b8b485aff0: Pull complete
# 699b75ff4717: Verifying Checksum
# 699b75ff4717: Download complete
# 077047c419c8: Download complete
# d887158cc58c: Pull complete
# dbbe367882c1: Download complete
# 6c07d6c25f33: Download complete
# 05895bb28c18: Pull complete
# baf7ab26f516: Pull complete
# 181182e3c9cf: Pull complete
# d584ef274e55: Pull complete
# d9ed46e4b5f9: Verifying Checksum
# d9ed46e4b5f9: Download complete
# c445dda55407: Pull complete
# 699b75ff4717: Pull complete
# b177109c9d16: Pull complete
# 59cea07bb66c: Pull complete
# d54d011de0e3: Pull complete
# b34fa6d447e9: Pull complete
# b8bdd3f19218: Pull complete
# 077047c419c8: Pull complete
# dbbe367882c1: Pull complete
# d9ed46e4b5f9: Pull complete
# 6c07d6c25f33: Pull complete
# Digest: sha256:7ed9a8b3227efd88871169aeb9fec695b0561934654512cc34891fd56aef73b8
# Status: Downloaded newer image for 8ee44115daec45588f306316a3c9ed45.azurecr.io/azureml/azureml_17b7ef3d4500f7b1271481f84603f948:latest
# 8ee44115daec45588f306316a3c9ed45.azurecr.io/azureml/azureml_17b7ef3d4500f7b1271481f84603f948:latest
# 2021-02-18T22:53:15Z Check if container house_price_predication_1613688085_86008573 already exist exited with 0,
#
#
# Streaming azureml-logs/75_job_post-tvmps_d367b920eebd3237b6d70e3c5f712e53282366890181684bec3c2019b09050c4_d.txt
# ===============================================================================================================
#
# [2021-02-18T22:53:46.463289] Entering job release
# [2021-02-18T22:53:48.190425] Starting job release
# [2021-02-18T22:53:48.201603] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 206
# [2021-02-18T22:53:48.202769] job release stage : upload_datastore starting...
# [2021-02-18T22:53:48.204037] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-02-18T22:53:48.204078] job release stage : execute_job_release starting...
# [2021-02-18T22:53:48.204326] job release stage : copy_batchai_cached_logs starting...
# [2021-02-18T22:53:48.206668] job release stage : copy_batchai_cached_logs completed...
# [2021-02-18T22:53:48.214838] Entering context manager injector.
# [2021-02-18T22:53:48.216774] job release stage : upload_datastore completed...
# [2021-02-18T22:53:48.482592] job release stage : send_run_telemetry starting...
# [2021-02-18T22:53:48.485810] job release stage : execute_job_release completed...
# [2021-02-18T22:53:49.377281] job release stage : send_run_telemetry completed...
# [2021-02-18T22:53:49.377626] Job release is complete
#
# Execution Summary
# =================
# RunId: House_Price_Predication_1613688085_86008573
# Web View: https://ml.azure.com/experiments/House_Price_Predication/runs/House_Price_Predication_1613688085_86008573?wsid=/subscriptions/6b4af8be-9931-443e-90f6-c4c34a1f9737/resourcegroups/aml-quickstarts-139150/workspaces/quick-starts-ws-139150
# {'runId': 'House_Price_Predication_1613688085_86008573',
#  'target': 'compute-cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2021-02-18T22:52:27.093993Z',
#  'endTimeUtc': '2021-02-18T22:54:01.16583Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'd7a4b334-4353-4681-a488-b35e13e3d2a1',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'train.py',
#   'command': '',
#   'useAbsolutePath': False,
#   'arguments': ['--kernel', 'linear', '--penalty', '1'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'compute-cluster',
#   'dataReferences': {},
#   'data': {},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': 2592000,
#   'nodeCount': 1,
#   'priority': None,
#   'credentialPassthrough': False,
#   'identity': None,
#   'environment': {'name': 'capstone-project-env',
#    'version': 'Autosave_2021-02-18T22:41:25Z_69c6d214',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['anaconda', 'conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-train-automl-runtime==1.21.0',
#         'inference-schema',
#         'azureml-interpret==1.21.0',
#         'azureml-defaults==1.21.0']},
#       'numpy>=1.16.0,<1.19.0',
#       'pandas==0.25.1',
#       'scikit-learn==0.22.1',
#       'xgboost<=1.3.3',
#       'psutil>=5.2.2,<6.0.0'],
#      'name': 'azureml_c577c941a77ed28f06a40cb408bf519d'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210104.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': False,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': True},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': None},
#   'aiSuperComputer': {'instanceType': None,
#    'frameworkImage': None,
#    'imageVersion': None,
#    'location': None,
#    'aiSuperComputerStorageData': None,
#    'interactive': False,
#    'scalePolicy': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'pyTorch': {'communicationBackend': None, 'processCount': None},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': False,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}},
#   'commandReturnCodeConfig': {'returnCode': 'Zero',
#    'successfulReturnCodes': []}},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=uBqPfDp9%2BT88Z8SBmNbzZMhSViyLVikuB%2B0dgqx8mRA%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_d367b920eebd3237b6d70e3c5f712e53282366890181684bec3c2019b09050c4_d.txt': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/azureml-logs/55_azureml-execution-tvmps_d367b920eebd3237b6d70e3c5f712e53282366890181684bec3c2019b09050c4_d.txt?sv=2019-02-02&sr=b&sig=zaXjZuFIDJLlKFxPokdxErv%2F7i8U%2F82iBupoaWhVZUM%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_d367b920eebd3237b6d70e3c5f712e53282366890181684bec3c2019b09050c4_d.txt': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/azureml-logs/65_job_prep-tvmps_d367b920eebd3237b6d70e3c5f712e53282366890181684bec3c2019b09050c4_d.txt?sv=2019-02-02&sr=b&sig=yl8pWaTcKgzHf8A3XZiwQP%2BvyZ3SelO5LXfyaNEZMzE%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=i7YFo%2B%2B5%2B6NBfZCs3fsgCNLCzsawcIzceL0iJFYzH68%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_d367b920eebd3237b6d70e3c5f712e53282366890181684bec3c2019b09050c4_d.txt': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/azureml-logs/75_job_post-tvmps_d367b920eebd3237b6d70e3c5f712e53282366890181684bec3c2019b09050c4_d.txt?sv=2019-02-02&sr=b&sig=MVNHSdfDWCZ0HcJufA9KCQrSI80l%2Bq0nGZ1YiO9pA9E%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r',
#   'azureml-logs/process_info.json': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=%2BPFUbaRqy50qkEOoGkuTOpmbjU3ZaD8EdwIjSPu6dCw%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r',
#   'azureml-logs/process_status.json': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=3AsqC88%2Bzn2sLbDL9JZ4AnMtdn%2BFuI%2F9ERsqIBPvXUA%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r',
#   'logs/azureml/104_azureml.log': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/logs/azureml/104_azureml.log?sv=2019-02-02&sr=b&sig=PAOmMaWxRH6WW4yaWJWDGPWlqTX4a4yx9uYJ%2Fd7NWn8%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=nCDu1eCv%2F6%2FUjZJiMB8ylHFjaMfLzBCq3Y4yRh9QRZw%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.House_Price_Predication_1613688085_86008573/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=tgvNYNAT%2BfNarQem0l3PsiCQBkfezFuYfcypd17d1ZY%3D&st=2021-02-18T22%3A43%3A57Z&se=2021-02-19T06%3A53%3A57Z&sp=r'},
#  'submittedBy': 'ODL_User 139150'}

# %% [markdown]
# # Tune model hyperparameters

# %%
from azureml.train.hyperdrive.runconfig import HyperDriveConfig
from azureml.train.hyperdrive.sampling import RandomParameterSampling
from azureml.train.hyperdrive.run import PrimaryMetricGoal
from azureml.train.hyperdrive.parameter_expressions import choice
    
booster=['gbtree','gblinear']
base_score=[0.25,0.5,0.75,1]

## Hyper Parameter Optimization
n_estimators = [100, 500, 900, 1100, 1500]
max_depth = [2, 3, 5, 10, 15]
booster=['gbtree','gblinear']
learning_rate=[0.05,0.1,0.15,0.20]
min_child_weight=[1,2,3,4]

# Define the grid of hyperparameters to search
hyperparameter_grid = RandomParameterSampling({
    'n_estimators': n_estimators,
    'max_depth':max_depth,
    'learning_rate':learning_rate,
    'min_child_weight':min_child_weight,
    'booster':booster,
    'base_score':base_score
    }
)
xgboost_model_regression = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 5, alpha = 10, n_estimators = 10)

hyperdrive_config = HyperDriveConfig(run_config=src,
                                     hyperparameter_sampling=hyperparameter_grid, 
                                     primary_metric_name='mean_squared_error',
                                     primary_metric_goal=PrimaryMetricGoal.MAXIMIZE,
                                     max_total_runs=50,
                                     max_concurrent_runs=4)

# hd_config = HyperDriveConfig(estimator=est,
#                                 hyperparameter_sampling=ps,
#                                 policy=early_termination_policy,
#                                 primary_metric_name='validation_acc',
#                                 primary_metric_goal=PrimaryMetricGoal.MAXIMIZE,
#                                 max_total_runs=4,
#                                 max_concurrent_runs=4)


# # Set up the random search with 4-fold cross validation
# random_cv = RandomizedSearchCV(estimator=regressor,
#             param_distributions=hyperparameter_grid,
#             cv=5, n_iter=50,
#             scoring = 'neg_mean_absolute_error',n_jobs = 4,
#             verbose = 5, 
#             return_train_score = True,
#             random_state=42)

# %%
# start the HyperDrive run
hyperdrive_run = experiment.submit(hyperdrive_config)

# %%
# Monitor HyperDrive runs

# %%
RunDetails(hyperdrive_run).show()
# Out:
# _HyperDriveWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': True, 'log_level': 'INFO',…

# %%
hyperdrive_run.wait_for_completion(show_output=True)
# Out:
# RunId: HD_609797ff-fa3d-4b85-bfde-f560216147ea
# Web View: https://ml.azure.com/experiments/House_Price_Predication/runs/HD_609797ff-fa3d-4b85-bfde-f560216147ea?wsid=/subscriptions/6b4af8be-9931-443e-90f6-c4c34a1f9737/resourcegroups/aml-quickstarts-139150/workspaces/quick-starts-ws-139150
#
# Streaming azureml-logs/hyperdrive.txt
# =====================================
#
# "<START>[2021-02-18T23:21:23.674941][API][INFO]Experiment created<END>\n""<START>[2021-02-18T23:21:24.281275][GENERATOR][INFO]Trying to sample '4' jobs from the hyperparameter space<END>\n""<START>[2021-02-18T23:21:25.064358][GENERATOR][INFO]Successfully sampled '1' jobs, they will soon be submitted to the execution target.<END>\n"<START>[2021-02-18T23:21:25.0353878Z][SCHEDULER][INFO]The execution environment is being prepared. Please be patient as it can take a few minutes.<END>"<START>[2021-02-18T23:21:54.696534][GENERATOR][INFO]Trying to sample '3' jobs from the hyperparameter space<END>\n""<START>[2021-02-18T23:21:55.507023][GENERATOR][INFO]Successfully sampled '1' jobs, they will soon be submitted to the execution target.<END>\n"<START>[2021-02-18T23:21:55.8138630Z][SCHEDULER][INFO]The execution environment was successfully prepared.<END><START>[2021-02-18T23:21:55.8148607Z][SCHEDULER][INFO]Scheduling job, id='HD_609797ff-fa3d-4b85-bfde-f560216147ea_0'<END>
#
# Execution Summary
# =================
# RunId: HD_609797ff-fa3d-4b85-bfde-f560216147ea
# Web View: https://ml.azure.com/experiments/House_Price_Predication/runs/HD_609797ff-fa3d-4b85-bfde-f560216147ea?wsid=/subscriptions/6b4af8be-9931-443e-90f6-c4c34a1f9737/resourcegroups/aml-quickstarts-139150/workspaces/quick-starts-ws-139150
# {'runId': 'HD_609797ff-fa3d-4b85-bfde-f560216147ea',
#  'target': 'compute-cluster',
#  'status': 'Canceled',
#  'startTimeUtc': '2021-02-18T23:21:23.416323Z',
#  'endTimeUtc': '2021-02-18T23:27:41.406258Z',
#  'error': {'error': {'code': 'UserError',
#    'message': 'User errors were found in at least one of the child runs.',
#    'messageParameters': {},
#    'details': []},
#   'time': '0001-01-01T00:00:00.000Z'},
#  'properties': {'primary_metric_config': '{"name": "mean_squared_error", "goal": "maximize"}',
#   'resume_from': 'null',
#   'runTemplate': 'HyperDrive',
#   'azureml.runsource': 'hyperdrive',
#   'platform': 'AML',
#   'ContentSnapshotId': 'd7a4b334-4353-4681-a488-b35e13e3d2a1'},
#  'inputDatasets': [],
#  'outputDatasets': [],
#  'logFiles': {'azureml-logs/hyperdrive.txt': 'https://mlstrg139150.blob.core.windows.net/azureml/ExperimentRun/dcid.HD_609797ff-fa3d-4b85-bfde-f560216147ea/azureml-logs/hyperdrive.txt?sv=2019-02-02&sr=b&sig=bgZQLfFVG%2F4%2BCNn%2FwTAeVShn81m6m%2BZRQ7IljJ%2BwUDQ%3D&st=2021-02-18T23%3A17%3A42Z&se=2021-02-19T07%3A27%3A42Z&sp=r'},
#  'submittedBy': 'ODL_User 139150'}

# %%
assert(hyperdrive_run.get_status() == "Completed")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-59-3e9f3ac98364> in <module>
# ----> 1 assert(hyperdrive_run.get_status() == "Completed")
#
# AssertionError:

# %% [markdown]
# # Find and register best model

# %%
best_run = hyperdrive_run.get_best_run_by_primary_metric()
print(best_run.get_details()['runDefinition']['arguments'])

# %%
print(best_run.get_file_names())

# %%
model = best_run.register_model(model_name='xgboost-house-price', model_path='outputs/model.joblib')
